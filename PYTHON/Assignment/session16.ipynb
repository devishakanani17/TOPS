# %%
# 1.
# Use iter() and next() to manually loop through a list of 5 trending movies from BookMyShow and print each
#  movie name one by one.

movie = ["After", "Stree2", "Dhurandhar", "Border 2", "Bhooth Bangla", "My Fault"]

it = iter(movie)

print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# After
# Stree2
# Dhurandhar
# Border 2
# Bhooth Bangla
# My Fault

# %%
# 2.
# Create a playlist of 6 songs (as a list of strings) and use enumerate() to print each song with its position 
# like Spotify's tracklist (e.g., '1. Kesariya').


songs = ["Kesariya", "Believer", "Shape of You", "Excuses", "Blinding Lights", "Perfect"]

for i, song in enumerate(songs, 1):
    print(i, ".", song)
# Out:
# 1 . Kesariya
# 2 . Believer
# 3 . Shape of You
# 4 . Excuses
# 5 . Blinding Lights
# 6 . Perfect

# %%
# 3.
# Given two lists — one of food items and one of prices — use zip() to print each food item with its price like 
# a Zomato menu (e.g., 'Pizza - ₹250').

food = ["Pizza", "Burger", "Mocktail"]
price = [250, 150, 200]

for food, price in zip(food, price):
    print(food, "- ₹", price)
# Out:
# Pizza - ₹ 250
# Burger - ₹ 150
# Mocktail - ₹ 200

# %%
# 4.
# Write a generator function called insta_posts_generator(posts) that takes a list of Instagram post captions 
# and yields one caption at a time. Use next() to get and print the next post caption each time until all captions 
# are printed.<br><br><em><strong>Hint:</strong> Use the yield keyword inside your function and handle StopIteration
#  when all posts are done.</em>

def insta_posts_generator(posts):
    for post in posts:
        yield post

posts = ["Vacation!", "New Photo", "Good Morning"]

gen = insta_posts_generator(posts)

try:
    while True:
        print(next(gen))
except StopIteration:
    print("No more posts")
# Out:
# Vacation!
# New Photo
# Good Morning
# No more posts

# %%
# 5.
# Build a generator function called cashback_generator(transactions) that takes a list of Paytm transaction amounts 
# and yields 5% cashback for each transaction. Print out the cashback values for all transactions.

def cashback_generator(transactions):
    for amount in transactions:
        yield amount * 0.05

transactions = [500, 1000, 2000]

for cashback in cashback_generator(transactions):
    print(cashback)
# Out:
# 25.0
# 50.0
# 100.0
